# %% [markdown]
# # **Tarea No. 1 - Física II**
#
#
# ***

# %% [markdown]
# El cuaderno Notebook de IPython está basado en la web y es muy interactivo. Un notebook en IPython es un documento  que contiene una lista ordenada de entradas/salidas las cuales pueden tener código, texto, matemáticas, dibujos, entre otras cosas. Los notebooks de IPython pueden ser convertidos a otros formatos de archivos como HTML, presentaciones de diapositivas, LaTeX, PDF, Python, etc).

# %% [markdown]
# # Proyecto Jupyter

# %% [markdown]
# El **proyecto Jupyter**, anteriormente conocido como el proyecto IPython, proporciona una colección de herramientas para la informática científica mediante eficaces shells interactivos que combinan la ejecución del código con la creación de documentos informáticos activos.

# %% [markdown]
# # Es posible incluir videos de youtube.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('-F4WS8o-G2A')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('KmzFDEu2RoA')

# %% [markdown]
# # Atractor de Lorentz

# %% [markdown]
# El atractor de Lorenz, concepto introducido por Edward Lorenz en 1963, es un sistema dinámico determinista tridimensional no lineal (wikipedia).

# %% [markdown]
# $$\frac {dx}{dt}=a(y-x)$$
# $$\frac {dy}{dt}=x(b-z)-y$$
# $$\frac {dz}{dt}=xy-cz$$

# %% [markdown]
# # Solución por el método de Runge - Kutta

# %%
from IPython.display import HTML
HTML('<iframe src=https://es.wikipedia.org/wiki/M%C3%A9todo_de_Runge-Kutta width=800px height=400px >')
# Out:
# <iframe src=https://es.wikipedia.org/wiki/M%C3%A9todo_de_Runge-Kutta width=800px height=400px >

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.mlab import griddata
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np
import sys


def ec1(t,x,y,z):
	return a1*(y-x)
def ec2(t, x, y, z):
	return (b1*x)-y-(x*z)
def ec3(t, x, y, z):
	return x*y - c1*z


a1=10
b1=28
c1=2.666666667
h = 0.01 
N = (50 - 0)/h 
t = 0 
x = 0 
y = 1 
z = 0 
i = 0

for i in range(2000): 

    k1 = h*ec1(t,x,y,z);
    l1 = h*ec2(t,x,y,z);
    g1 = h*ec3(t,x,y,z);

    t1 = t + 0.5*h;
    x1 = x + k1/2;
    y1 = y + l1/2;
    z1 = z + g1/2;

    k2 = h*ec1(t1,x1,y1,z1);
    l2 = h*ec2(t1,x1,y1,z1);
    g2 = h*ec3(t1,x1,y1,z1);

    t2 = t+0.5*h;
    y2 = y + l2/2;
    x2 = x + k2/2;
    z2 = z + g2/2;

    k3 = h*ec1(t2,x2,y2,z2);
    l3 = h*ec2(t2,x2,y2,z2);
    g3 = h*ec3(t2,x2,y2,z2);

    t3 = t + h;
    y3 = y + l3;
    x3 = x + k3;
    z3 = z + g3;

    k4 = h*ec1(t3,x3,y3,z3);
    l4 = h*ec2(t3,x3,y3,z3);
    g4 = h*ec3(t3,x3,y3,z3);

    t = t+h;
    x = x + 0.166666667*(k1+(2*k2)+(2*k3)+k4);
    y = y + 0.166666667*(l1+(2*l2)+(2*l3)+l4);
    z = z + 0.166666667*(g1+(2*g2)+(2*g3)+g4);
    #print(x,y,z)
    
    
    data = open("data_atractor.txt","a+")
    data.write(str(x)+"\t"+str(y)+"\t"+str(z)+'\n')
    data.close()
    
    
thedata = np.genfromtxt('data_atractor.txt',delimiter='\t',usecols=(0,1,2),names=['a','b','c'])
fig = plt.figure()
ax = fig.gca(projection='3d')
#ax.view_init(elev=15, azim=60) 
ax.scatter(thedata['a'], thedata['b'], thedata['c'],marker='.',s=5)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
# Out:
# /home/karla/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt 
plt.plotfile('data_atractor.txt', delimiter='\t', cols=(0,1), names=('x', 'y'), marker='.',color='r')
plt.show()

# %% [markdown]
# # Ejemplos

# %% [markdown]
# 1. [Trump](http://nbviewer.jupyter.org/github/bkrakauer/trumptweets/blob/master/Trump%20Tweet%20Source.ipynb)
# 2. [LIGO](https://github.com/minrk/ligo-binder/blob/master/GW150914_tutorial.ipynb)
# 3. [Tres](http://nbviewer.jupyter.org/github/pjpmarques/Julia-Modeling-the-World/blob/master/Three-Body%20Problem.ipynb)
# 3. [Nature](http://www.nature.com/news/ipython-interactive-demo-7.21492)
# 4. [Homework](http://nbviewer.jupyter.org/github/mikigom/mikigom_course/blob/master/MC3204/HW01/HW01.ipynb)
# 5. [varios](http://nb.bianp.net/)
# 6. [github](https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks)
